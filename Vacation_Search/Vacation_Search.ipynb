# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_Database.csv")

# Display sample data
city_data_df.drop(columns=["Unnamed: 0"], inplace=True)
city_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22164\2521887187.py in <module>
#       1 # Import the WeatherPy_database.csv file.
# ----> 2 city_data_df = pd.read_csv("Weather_Database/WeatherPy_Database.csv")
#       3
#       4 # Display sample data
#       5 city_data_df.drop(columns=["Unnamed: 0"], inplace=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 60
# What is the maximum temperature you would like for your trip? 80

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] >= min_temp) & (city_data_df["Max Temp"] <= max_temp)]

# Display sample data
preferred_cities_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 2  Puerto Ayora      EC  -0.7393  -90.3518     75.54        95          67
# 3       Rikitea      PF -23.1203 -134.9692     77.79        68           2
# 4       Mataura      NZ -46.1927  168.8643     68.59        51          87
# 7  Sungai Besar      MY   3.6746  100.9867     77.23        81         100
# 9  Mizan Teferi      ET   6.9833   35.5833     60.96        67          79
#
#    Wind Speed Current Description
# 2        5.86       broken clouds
# 3        5.79           clear sky
# 4        6.44     overcast clouds
# 7        4.81     overcast clouds
# 9        2.82       broken clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities = preferred_cities_df.dropna(how="any")

# Display sample data
clean_travel_cities.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 2  Puerto Ayora      EC  -0.7393  -90.3518     75.54        95          67
# 3       Rikitea      PF -23.1203 -134.9692     77.79        68           2
# 4       Mataura      NZ -46.1927  168.8643     68.59        51          87
# 7  Sungai Besar      MY   3.6746  100.9867     77.23        81         100
# 9  Mizan Teferi      ET   6.9833   35.5833     60.96        67          79
#
#    Wind Speed Current Description
# 2        5.86       broken clouds
# 3        5.79           clear sky
# 4        6.44     overcast clouds
# 7        4.81     overcast clouds
# 9        2.82       broken clouds

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"] = ""
hotel_df = hotel_df.reset_index(drop=True)
# Display sample data
hotel_df.head()
# Out:
#            City Country  Max Temp Current Description      Lat       Lng  \
# 0  Puerto Ayora      EC     75.54       broken clouds  -0.7393  -90.3518
# 1       Rikitea      PF     77.79           clear sky -23.1203 -134.9692
# 2       Mataura      NZ     68.59     overcast clouds -46.1927  168.8643
# 3  Sungai Besar      MY     77.23     overcast clouds   3.6746  100.9867
# 4  Mizan Teferi      ET     60.96       broken clouds   6.9833   35.5833
#
#   Hotel Name
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Mataura - nearest hotel: No hotel found
# Sungai Besar - nearest hotel: Green Hotel
# Mizan Teferi - nearest hotel: ሆቴል ሳላይሽ / Salayesh Hotel
# Port Alfred - nearest hotel: No hotel found
# Sur - nearest hotel: Sur Hotel
# Tena - nearest hotel: Hotel Villa Belén
# Chuy - nearest hotel: Alerces
# Payo - nearest hotel: No hotel found
# Rio Grande - nearest hotel: Hotel Vila Moura Executivo
# Mwinilunga - nearest hotel: No hotel found
# Hermanus - nearest hotel: Aloe guest house
# Bambous Virieux - nearest hotel: No hotel found
# Xuddur - nearest hotel: No hotel found
# Busselton - nearest hotel: No hotel found
# Rio Blanco - nearest hotel: Hotel La Laguna
# Kaitangata - nearest hotel: No hotel found
# Itaituba - nearest hotel: TG Hotel
# Puerto Maldonado - nearest hotel: Puerto Palmeras
# Atuona - nearest hotel: Pearl Resort
# Acari - nearest hotel: No hotel found
# Mar Del Plata - nearest hotel: Nuevo Ostende
# Carnarvon - nearest hotel: No hotel found
# Kavaratti - nearest hotel: No hotel found
# Mahibadhoo - nearest hotel: Coral View Inn
# Antofagasta - nearest hotel: Hotel Colón
# Waipawa - nearest hotel: No hotel found
# Ayakudi - nearest hotel: Royal park
# Wellington - nearest hotel: Travelodge
# Inhambane - nearest hotel: Hotel de Inhambane
# Tombouctou - nearest hotel: No hotel found
# Port Lincoln - nearest hotel: Boston Hotel
# Esperance - nearest hotel: Hospitality
# Hilo - nearest hotel: Dolphin Bay Hotel
# Cidreira - nearest hotel: Hotel Castelo
# Altamira - nearest hotel: Hotel Vale do Xingu
# San Luis - nearest hotel: Hotel Dos Venados
# Torrevieja - nearest hotel: Hotel Fontana Plaza
# Camopi - nearest hotel: Chez Lucia
# Atar - nearest hotel: فندق سكليل
# Coquimbo - nearest hotel: Hotel Iberia
# Souillac - nearest hotel: Hotel SkylineInn
# Almeirim - nearest hotel: Kapejar Hotel
# Bluff - nearest hotel: No hotel found
# Sompeta - nearest hotel: No hotel found
# Conde - nearest hotel: Paladino
# Upata - nearest hotel: Hotel Garibardi
# Cayenne - nearest hotel: Central Hôtel
# Zuenoula - nearest hotel: Hotel le Prestige
# East London - nearest hotel: No hotel found
# Taoudenni - nearest hotel: No hotel found
# Puerto Escondido - nearest hotel: Hotel Barlovento
# Banikoara - nearest hotel: No hotel found
# Port Elizabeth - nearest hotel: Waterford Hotel
# Humaita - nearest hotel: Humaita Quality Hotel
# Castro - nearest hotel: Hotel Central Palace
# Grand Gaube - nearest hotel: Coco Villa
# Porto Novo - nearest hotel: Hôtel 6500 CFA
# Gorom-Gorom - nearest hotel: No hotel found
# Anastacio - nearest hotel: Hotel Araras
# Hithadhoo - nearest hotel: Pebbles Inn
# Arraial Do Cabo - nearest hotel: No hotel found
# Nova Londrina - nearest hotel: Hotel Felice
# Minab - nearest hotel: هتل صدف
# Tuatapere - nearest hotel: No hotel found
# Savalou - nearest hotel: BENIN CALYPSO Hôtel
# Maraba - nearest hotel: Portobelo
# Cockburn Town - nearest hotel: The Salt Raker Inn
# San Patricio - nearest hotel: No hotel found
# Mahebourg - nearest hotel: Grand Bel Air
# Prado - nearest hotel: Pousada Recanto do Prado
# Gamba - nearest hotel: No hotel found
# Vila Velha - nearest hotel: Hotel Prainha
# Cape Town - nearest hotel: Townhouse Hotel
# Saint-Philippe - nearest hotel: Le Baril
# Mirador - nearest hotel: No hotel found
# Shakawe - nearest hotel: No hotel found
# Puerto Leguizamo - nearest hotel: Hotel Girasoles
# Marawi - nearest hotel: Marawi Resort Hotel
# Giyani - nearest hotel: No hotel found
# Bredasdorp - nearest hotel: Victoria Hotel
# Trairi - nearest hotel: No hotel found
# Isla Mujeres - nearest hotel: Villa La Bella
# Nisia Floresta - nearest hotel: No hotel found
# Vao - nearest hotel: Nataiwatch
# Salalah - nearest hotel: Muscat International Hotel
# Alta Floresta - nearest hotel: Villas Hotel
# Wanganui - nearest hotel: The Grand Hotel
# Taltal - nearest hotel: Hostería Taltal
# Rocha - nearest hotel: Hotel Municipal
# Itarema - nearest hotel: Pousada Oásis
# Nizwa - nearest hotel: Nizwa Heritage Inn
# Richards Bay - nearest hotel: Protea Hotel
# Chicama - nearest hotel: No hotel found
# Jatibonico - nearest hotel: La Moderna
# Puerto Del Rosario - nearest hotel: Hotel Tamasite
# San Carlos - nearest hotel: Hotel Villas del Norte
# Sangmelima - nearest hotel: Hôtel l'Afamba
# Cabo San Lucas - nearest hotel: Comfort Rooms
# La Trinidad - nearest hotel: Pine Valley Convention Center
# Sembe - nearest hotel: No hotel found
# Moissala - nearest hotel: No hotel found
# Sao Jose Da Coroa Grande - nearest hotel: Hotel do Sol
# Namibe - nearest hotel: Hotel Chik Chik Namibe
# Guadalupe - nearest hotel: Hotel Ejecutivo
# Tessalit - nearest hotel: No hotel found
# Ahipara - nearest hotel: YHA Ahipara
# Cartagena - nearest hotel: Hotel Bellamar
# Viedma - nearest hotel: Níjar
# Sabang - nearest hotel: Sabang Hill
# Sao Joao Da Barra - nearest hotel: Pousada Mediterrâneo
# Saint-Georges - nearest hotel: Deyna's City Inn
# Los Llanos De Aridane - nearest hotel: Valle Aridane
# Inyonga - nearest hotel: Mikumi Lodge
# Touros - nearest hotel: Pousada Atlântico
# Araouane - nearest hotel: No hotel found
# Kollam - nearest hotel: Sea Palace
# Salinopolis - nearest hotel: Hotel Salinópolis
# Doha - nearest hotel: Al MIrqab
# Bubaque - nearest hotel: Chez Julio
# Vangaindrano - nearest hotel: Fanilo
# Saint-Pierre - nearest hotel: Tropic Hotel
# Estelle - nearest hotel: No hotel found
# Key Largo - nearest hotel: Key Largo Inn
# Cascais - nearest hotel: Cascais Hotel
# Axim - nearest hotel: Axim Beach Hotel
# Banda Aceh - nearest hotel: Hotel 61
# Rusape - nearest hotel: No hotel found
# Les Cayes - nearest hotel: No hotel found
# Bryan - nearest hotel: The Lasalle Hotel
# Rawson - nearest hotel: Hotel Deportivo
# Fayaoue - nearest hotel: Hôtel Beaupré
# Bangui - nearest hotel: Hotel Levy's
# Mogadishu - nearest hotel: SYL Hotel
# Resplendor - nearest hotel: Brito Hotel
# Akim Swedru - nearest hotel: No hotel found
# Pisco - nearest hotel: La Portada
# Morondava - nearest hotel: Hotel Sharon Menabe
# Muscat - nearest hotel: البطاشي
# Koungou - nearest hotel: Hôtel Trévani
# Port Blair - nearest hotel: Andaman Ocean Breeze
# La Libertad - nearest hotel: Hotel Mar Caribe
# Laureles - nearest hotel: No hotel found
# Kaeo - nearest hotel: No hotel found
# Lima - nearest hotel: Hotel Peach Garden
# Kinwat - nearest hotel: No hotel found
# Choix - nearest hotel: No hotel found
# Jacala - nearest hotel: Marely
# Omboue - nearest hotel: Georges Faustin Aurat
# Tautira - nearest hotel: No hotel found
# Geraldton - nearest hotel: Ocean Centre Hotel
# Praia - nearest hotel: Casa Sodadi
# Maceio - nearest hotel: Maceió Hostel e Pousada
# Valparaiso - nearest hotel: Ibis Hotel
# Guerrero Negro - nearest hotel: Plaza sal paraiso
# Ishigaki - nearest hotel: アートホテル石垣島
# Urubicha - nearest hotel: No hotel found
# Ritchie - nearest hotel: No hotel found
# Airai - nearest hotel: No hotel found
# Adeje - nearest hotel: Royal Garden Villas
# Jeremie - nearest hotel: Delivrance Hotel
# Takoradi - nearest hotel: Hillcrest
# Santa Cruz - nearest hotel: Aviador Hotel Boutique
# Monrovia - nearest hotel: Bella Casa Hotel
# Huarmey - nearest hotel: Hostal Santa Rosa
# Ettaiyapuram - nearest hotel: No hotel found
# Jardim - nearest hotel: Hotel Uchôa
# Panaba - nearest hotel: No hotel found
# Santa Cruz De La Palma - nearest hotel: El Hotelito 27
# Amapa - nearest hotel: No hotel found
# Mfou - nearest hotel: No hotel found
# Wamba - nearest hotel: No hotel found
# Digapahandi - nearest hotel: No hotel found
# Coahuayana - nearest hotel: No hotel found
# Boa Vista - nearest hotel: Aipana Plaza Hotel
# Saint-Louis - nearest hotel: No hotel found
# Trelew - nearest hotel: Patagonia Suites & Apart
# Teknaf - nearest hotel: No hotel found
# Capao Da Canoa - nearest hotel: Hotel Serramar
# Sebina - nearest hotel: No hotel found
# Nouadhibou - nearest hotel: Hotel valencia
# Beloha - nearest hotel: No hotel found
# Aripuana - nearest hotel: No hotel found
# Mocuba - nearest hotel: No hotel found
# Bulawayo - nearest hotel: Selboune Hotel
# Cap Malheureux - nearest hotel: Cape Garden
# Bodden Town - nearest hotel: Turtle Nest Inn
# Cantaura - nearest hotel: No hotel found
# Abu Zabad - nearest hotel: No hotel found
# Bulungu - nearest hotel: No hotel found
# Thinadhoo - nearest hotel: No hotel found
# Ixtapa - nearest hotel: No hotel found
# Sao Felix Do Xingu - nearest hotel: Hotel Terraço
# Santa Flavia - nearest hotel: Villa Soles
# Gra Liyia - nearest hotel: No hotel found
# Adrar - nearest hotel: No hotel found
# Kalmunai - nearest hotel: Saji new food
# Cabedelo - nearest hotel: No hotel found
# Loanda - nearest hotel: Hotel Forum
# Khudumelapye - nearest hotel: No hotel found
# Comodoro Rivadavia - nearest hotel: No hotel found
# Nieuw Amsterdam - nearest hotel: Leonsberg Lodge
# Sitio Novo Do Tocantins - nearest hotel: New Anápolis Hotel
# Neuquen - nearest hotel: Hotel Argentina 307
# Kapiri Mposhi - nearest hotel: Chanika Lodge
# Tres Arroyos - nearest hotel: Andrea Hotel
# Paita - nearest hotel: Victor's
# Leon Valley - nearest hotel: In Town Suites Leon Valley North
# Malangali - nearest hotel: No hotel found
# Ambilobe - nearest hotel: Hôtel National
# Bridgetown - nearest hotel: Radisson Aquatica Resort
# Acapulco - nearest hotel: Hotel del Valle
# Arlit - nearest hotel: No hotel found
# Sinnamary - nearest hotel: Hôtel du fleuve
# Te Anau - nearest hotel: Lakeside Motels & Apartments
# Sao Filipe - nearest hotel: Bela Vista
# Christchurch - nearest hotel: Ibis Hotel Christchurch
# Vilhena - nearest hotel: No hotel found
# San Cristobal - nearest hotel: Terra Sur
# Balugaon - nearest hotel: No hotel found
# Ngaoundere - nearest hotel: LA CONCORDE
# Bay Saint Louis - nearest hotel: Pearl Hotel
# Lazaro Cardenas - nearest hotel: Hotel Sol del Pacífico
# Mesetas - nearest hotel: Hotel Doña BETY
# Copala - nearest hotel: No hotel found
# Yanam - nearest hotel: No hotel found
# Kasempa - nearest hotel: Kasmpa Council Guest House
# Wanlaweyn - nearest hotel: No hotel found
# Chalisgaon - nearest hotel: No hotel found
# Businga - nearest hotel: Hôtel Roho
# Anaco - nearest hotel: Hotel Muñíz
# Gushikawa - nearest hotel: No hotel found
# Mwene-Ditu - nearest hotel: Hôtel KAMAS
# Benguela - nearest hotel: Hotel Moibela
# Belmonte - nearest hotel: No hotel found
# Frederico Westphalen - nearest hotel: No hotel found
# Puerto Baquerizo Moreno - nearest hotel: Dory's House
# Quelimane - nearest hotel: Mabassa
# Domoni - nearest hotel: Hotel Djadid
# Kruisfontein - nearest hotel: No hotel found
# Baracoa - nearest hotel: Casa
# Raga - nearest hotel: No hotel found
# Bartica - nearest hotel: Rockville Hotel
# Savannah Bight - nearest hotel: La Giralda
# Caravelas - nearest hotel: Pousada dos Navegantes
# Tezu - nearest hotel: No hotel found
# Bathsheba - nearest hotel: Atlantis Hotel
# Linhares - nearest hotel: Days Inn Linhares
# Kingston - nearest hotel: Aphrodite Hotel
# Gogrial - nearest hotel: No hotel found
# Gibara - nearest hotel: Plaza Colón
# Yarada - nearest hotel: No hotel found
# Yangambi - nearest hotel: No hotel found
# Freetown - nearest hotel: Formal Leona hotel
# Grand Baie - nearest hotel: Safari
# Cinco Esquinas - nearest hotel: Hotel El Portico
# Tutoia - nearest hotel: Pousada San Vicente
# Methoni - nearest hotel: Hotel Ulysses
# Wajid - nearest hotel: No hotel found
# Burnie - nearest hotel: Burnie Central TownHouse Hotel
# Grand-Bourg - nearest hotel: Coco Beach Resort
# Porto Murtinho - nearest hotel: Hotel Saladero Cuê
# Cradock - nearest hotel: Die Tuishuise and Victoria Manor
# Waitara - nearest hotel: No hotel found
# Arenys De Mar - nearest hotel: Hotel Jet
# Goundam - nearest hotel: No hotel found
# Dubti - nearest hotel: No hotel found
#               City Country  Max Temp Current Description      Lat       Lng  \
# 0     Puerto Ayora      EC     75.54       broken clouds  -0.7393  -90.3518
# 1          Rikitea      PF     77.79           clear sky -23.1203 -134.9692
# 2          Mataura      NZ     68.59     overcast clouds -46.1927  168.8643
# 3     Sungai Besar      MY     77.23     overcast clouds   3.6746  100.9867
# 4     Mizan Teferi      ET     60.96       broken clouds   6.9833   35.5833
# ..             ...     ...       ...                 ...      ...       ...
# 263        Cradock      ZA     71.85     overcast clouds -32.1642   25.6192
# 264        Waitara      NZ     68.99           clear sky -38.9250  174.2500
# 265  Arenys De Mar      ES     62.38     overcast clouds  41.5819    2.5494
# 266        Goundam      ML     66.36       broken clouds  16.4145   -3.6708
# 267          Dubti      ET     69.44           clear sky  11.7361   41.0853
#
#                                Hotel Name
# 0    Hostal La Mirada De Solitario George
# 1                    Chez Bianca & Benoit
# 2                          No hotel found
# 3                             Green Hotel
# 4               ሆቴል ሳላይሽ / Salayesh Hotel
# ..                                    ...
# 263      Die Tuishuise and Victoria Manor
# 264                        No hotel found
# 265                             Hotel Jet
# 266                        No hotel found
# 267                        No hotel found
#
# [268 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df[hotel_df["Hotel Name"] != "No hotel found"]

# Display sample data
clean_hotel_df.head()
# Out:
#            City Country  Max Temp Current Description      Lat       Lng  \
# 0  Puerto Ayora      EC     75.54       broken clouds  -0.7393  -90.3518
# 1       Rikitea      PF     77.79           clear sky -23.1203 -134.9692
# 3  Sungai Besar      MY     77.23     overcast clouds   3.6746  100.9867
# 4  Mizan Teferi      ET     60.96       broken clouds   6.9833   35.5833
# 6           Sur      OM     67.21       broken clouds  22.5667   59.5289
#
#                              Hotel Name
# 0  Hostal La Mirada De Solitario George
# 1                  Chez Bianca & Benoit
# 3                           Green Hotel
# 4             ሆቴል ሳላይሽ / Salayesh Hotel
# 6                             Sur Hotel

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_file = "Vacation_Search/WeatherPy_vacation.csv"

# Export the City_Data into a csv
clean_hotel_df.to_csv(output_file)

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot

hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 500,
    frame_height = 300,
    size = "Max Temp",
    scale = .5,
    color = "City",
    hover_cols = ["Hotel Name", "Country", "Current Description"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country,Current Description)
