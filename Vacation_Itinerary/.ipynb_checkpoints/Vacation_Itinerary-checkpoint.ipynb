# %% [markdown]
# # Deliverable 3. Create a Travel Itinerary Map
#
# ----
#
# 1. Create a folder called `Vacation_Itinerary` to store all the files for this deliverable.
#
# 2. Download the `Vacation_Itinerary_starter_code.ipynb` file into your `Vacation_Itinerary` folder and rename it `Vacation_Itinerary.ipynb`.
#
# 3. Make sure the initial dependencies and the Geoapify API key are imported.
#
# 4. From your `Vacation_Search` folder from Deliverable 2, import the `WeatherPy_vacation.csv` file as a DataFrame named `vacation_df`.
#
# 5. Use GeoViews to create a map that shows all the cities in the `vacation_df` DataFrame. Configure the map as follows:
#
#     * The point's size should be the maximum temperature for the city
#
#     * The point's color should be the city's name
#
#     * Use the `hover_cols` parameter to the the "Hotel Name", "Country", and "Current Description" columns to each point as additional information.
#
# 6. From the map, *choose four cities* that a customer might want to visit. They should be close together and in the same country. Use the `loc` method to create separate DataFrames for each city on the travel route.
#
#     > **Hint:** You will start and end the route in the same city, so the `vacation_start` and `vacation_end` DataFrames will be in the same city.
#
# 7. Use the Pandas `concat` function to merge the DataFrame from each city in the itinerary to create a new DataFrame named `itinerary_df` to store the itinerary details.
#
# 8. Use the Pandas `copy` function to create a new DataFrame named `waypoints_df` to store the longitude and latitude for each city in `itinerary_df`.
#
#     > **Hint:** You'll use this DataFrame to create a map using GeoViews, so recall that the first column should be the longitude, and the second the latitude.
#
# 9. Use GeoViews to create a map that shows the four cities in the itinerary.
#
# 10. Next, you'll use the Geoapify Routing API to find a route between the cities in the itinerary. Review the code that sets the initial parameters and fetches the coordinates from each city to define the `waypoints` parameter by using a `for` loop.
#
#     > **Hint:** You can note that the `mode` parameter is set to `drive`, you can play around with other modes as it's shown in [the "Travel modes" table](https://apidocs.geoapify.com/docs/routing/#api) in the Geoapify Routing API documentation.
#
# 11. Use the Geoapify Routing API to retrieve the route's directions for your itinerary.
#
# 12. From the JSON response, store the route's legs coordinates in a variable called `legs`.
#
# 13. Loop through the route legs coordinates to fetch the latitude and longitude for each step. Store the latitude and longitude values into two Python lists named `longitude` and `latitude`.
#
# 14. Use the `longitude` and `latitude` Python lists to create a new DataFrame named `route_df`.
#
# 15. Use the GeoViews `Path` function to configure a line plot by using `route_df`. Set a custom color and width for the line that may contrast with the map.
#
# 16. Use the asterisk operator to display a composed plot that shows the itinerary's route over the map containing the cities.
#
# 17. Save your map to the `Vacation_Itinerary` folder as `WeatherPy_travel_map.png`.
#
# ---

# %% [markdown]
# ## Make sure the initial dependencies and the Geoapify API key are imported

# %%
# Dependencies and Setup
import geoviews as gv
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From your `Vacation_Search` folder from Deliverable 2, import the `WeatherPy_vacation.csv` file as a DataFrame named `vacation_df`

# %%
# Read the WeatherPy_vacation.csv into a DataFrame
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.drop(columns="Unnamed: 0", inplace=True)
# Display sample data
vacation_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25044\2649411905.py in <module>
#       1 # Read the WeatherPy_vacation.csv into a DataFrame
# ----> 2 vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
#       3 vacation_df.drop(columns="Unnamed: 0", inplace=True)
#       4 # Display sample data
#       5 vacation_df.head(10)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Vacation_Search/WeatherPy_vacation.csv'

# %% [markdown]
# ## Use GeoViews to create a map that shows all the cities in the `vacation_df` DataFrame. Configure the map as follows:
#
# * The point's size should be the maximum temperature for the city
#
# * The point's color should be the city's name
#
# * Use the `hover_cols` parameter to the the "Hotel Name", "Country", and "Current Description" columns to each point as additional information.

# %%
# Configure the map plot
map_plot = vacation_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = .5,
    color = "City",
    hover_cols = ["Hotel Name", "Country", "Current Description"]
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country,Current Description)

# %% [markdown]
# ## From the map, *choose four cities* that a customer might want to visit. They should be close together and in the same country. Use the `loc` method to create separate DataFrames for each city on the travel route.

# %%
# Create DataFrames for each city by filtering the 'vacation_df' using the loc method
vacation_start = vacation_df[vacation_df["City"] == "Rio Blanco"]
vacation_end = vacation_df[vacation_df["City"] == "Rio Blanco"]
stop_1 = vacation_df[vacation_df["City"] == "Puerto Escondido"]
stop_2 = vacation_df[vacation_df["City"] == "Cabo San Lucas"]
stop_3 = vacation_df[vacation_df["City"] == "Jacala"]

# %% [markdown]
# ## Use the Pandas `concat` function to merge the DataFrame from each city in the itinerary to create a new DataFrame named `itinerary_df` to store the itinerary details

# %%
# Use the Pandas concat function to create a new DataFrame to store the itinerary details.
itinerary_df = pd.concat([vacation_start, vacation_end, stop_1, stop_2, stop_3])

# Display sample data
itinerary_df
# Out:
#                  City Country  Max Temp Current Description      Lat  \
# 9          Rio Blanco      MX     63.54    scattered clouds  18.8333
# 9          Rio Blanco      MX     63.54    scattered clouds  18.8333
# 35   Puerto Escondido      MX     79.63       broken clouds  15.8500
# 70     Cabo San Lucas      MX     71.51    scattered clouds  22.8909
# 107            Jacala      MX     60.93     overcast clouds  21.0167
#
#           Lng        Hotel Name
# 9    -97.1500   Hotel La Laguna
# 9    -97.1500   Hotel La Laguna
# 35   -97.0667  Hotel Barlovento
# 70  -109.9124     Comfort Rooms
# 107  -99.1833            Marely

# %% [markdown]
# ## Use the Pandas `copy` function to create a new DataFrame named `waypoints_df` to store the longitude and latitude for each city in `itinerary_df`

# %%
# Create a Pandas DataFrame to store the latitude and longitude for each city in the itineray
waypoints_df = itinerary_df[["Lat", "Lng"]]

# Display sample data
waypoints_df
# Out:
#          Lat       Lng
# 9    18.8333  -97.1500
# 9    18.8333  -97.1500
# 35   15.8500  -97.0667
# 70   22.8909 -109.9124
# 107  21.0167  -99.1833

# %% [markdown]
# ## Use GeoViews to create map that shows the four cities in the itinerary

# %%
# Configure the map plot by using the itineraty_df
waypoints_map = itinerary_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = .5,
    color = "City",
    hover_cols = ["Hotel Name", "Country", "Current Description"]
)

# %%
# Display the route_map
waypoints_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country,Current Description)

# %% [markdown]
# ## Next, you'll use the Geoapify Routing API to find a route between the cities in the itinerary. Review the code that sets the initial parameters and fetches the coordinates from each city to define the `waypoints` parameter by using a `for` loop

# %%
# Set parameters to trace the route
radius = 5000
params = {
    "mode":"drive",
    "apiKey": geoapify_key,
}

# %%
# Set an empty waypoints String variable
waypoints = ""

# Iterate through the route_df DataFrame to define the waypoints
for index, row in waypoints_df.iterrows():
    waypoints = waypoints + str(row["Lat"]) + "," + str(row["Lng"]) + "|"

# Delete the last character from the string
waypoints = waypoints[:-1]

# Add the waypoints to the params dictionary
params["waypoints"] = waypoints

# Display the params dictionary
params
# Out:
# {'mode': 'drive',
#  'apiKey': '77fd1afd10d84048851bdecbbaf8cbcf',
#  'waypoints': '18.8333,-97.15|18.8333,-97.15|15.85,-97.0667|22.8909,-109.9124|21.0167,-99.1833'}

# %% [markdown]
# ## Use the Geoapify Routing API to retrieve the route's directions for your itinerary

# %%
# Set up the base URL for the Geoapify Places API.
base_url = "https://api.geoapify.com/v1/routing"

# Make request and retrieve the JSON data by using the params dictionaty
route_response = requests.get(base_url, params=params)

# Convert the API response to JSON format
route_response = route_response.json()
route_response
# Out:
# {'features': [{'type': 'Feature',
#    'properties': {'mode': 'drive',
#     'waypoints': [{'location': [-97.15, 18.8333], 'original_index': 0},
#      {'location': [-97.15, 18.8333], 'original_index': 1},
#      {'location': [-97.0667, 15.85], 'original_index': 2},
#      {'location': [-109.9124, 22.8909], 'original_index': 3},
#      {'location': [-99.1833, 21.0167], 'original_index': 4}],
#     'units': 'metric',
#     'distance': 9378063,
#     'distance_units': 'meters',
#     'time': 371122.552,
#     'legs': [{'distance': 0,
#       'time': 0,
#       'steps': [{'from_index': 0,
#         'to_index': 1,
#         'distance': 0,
#         'time': 0,
#         'instruction': {'text': 'Drive north on Avenida Venustiano Carranza.'}},
#        {'from_index': 1,
#         'to_index': 1,
#         'distance': 0,
#         'time': 0,
#         'instruction': {'text': 'Your destination is on the left.'}}]},
#      {'distance': 529109,
#       'time': 23293.818,
#       'steps': [{'from_index': 0,
#         'to_index': 3,
#         'distance': 292,
#         'time': 30.087,
#         'instruction': {'text': 'Drive southwest on Avenida Venustiano Carranza.'}},
#        {'from_index': 3,
#         'to_index': 10,
#         'distance': 115,
#         'time': 12.01,
#         'instruction': {'text': 'Turn right onto Calle Benito Juárez.'}},
#        {'from_index': 10,
#         'to_index': 23,
#         'distance': 457,
#         'time': 49.327,
#         'instruction': {'text': 'Turn right onto Avenida Oaxaca.'}},
#        {'from_index': 23,
#         'to_index': 562,
#         'distance': 27677,
#         'time': 1383.364,
#         'instruction': {'text': 'Turn left onto Avenida México/MEX 150. Continue on MEX 150.'}},
#        {'from_index': 562,
#         'to_index': 646,
#         'distance': 1695,
#         'time': 81.736,
#         'instruction': {'text': 'Turn right onto Orizaba - Tehuacán/MEX 150.'}},
#        {'from_index': 646,
#         'to_index': 1128,
#         'distance': 31124,
#         'time': 1534.982,
#         'instruction': {'text': 'Turn right onto Orizaba - Tehuacán/MEX 150.'}},
#        {'from_index': 1128,
#         'to_index': 1161,
#         'distance': 3088,
#         'time': 156.017,
#         'instruction': {'text': 'Bear right onto Carretera Federal Puebla-Tehuacán/MEX 150.'}},
#        {'from_index': 1161,
#         'to_index': 1177,
#         'distance': 415,
#         'time': 20.049,
#         'instruction': {'text': 'Bear left onto Carretera Federal Puebla-Tehuacán/MEX 150. Continue on MEX 150.'}},
#        {'from_index': 1177,
#         'to_index': 2708,
#         'distance': 203932,
#         'time': 6999.195,
#         'instruction': {'text': 'Take the MEX 135D ramp.'},
#         'toll': True},
#        {'from_index': 2708,
#         'to_index': 2824,
#         'distance': 8090,
#         'time': 399.089,
#         'instruction': {'text': 'Bear right onto MEX 190/Carretera Oaxaca - México. Continue on MEX 190.'}},
#        {'from_index': 2824,
#         'to_index': 2833,
#         'distance': 430,
#         'time': 28.876,
#         'instruction': {'text': 'Bear right onto Carretera Panamericana (Carretera internacional Cristóbal Colón)/MEX 190.'}},
#        {'from_index': 2833,
#         'to_index': 2865,
#         'distance': 1492,
#         'time': 112.258,
#         'instruction': {'text': 'Keep left to take Calzada Francisco I. Madero.'}},
#        {'from_index': 2865,
#         'to_index': 2913,
#         'distance': 1916,
#         'time': 121.635,
#         'instruction': {'text': 'Bear right onto Boulevard Eduardo Mata.'}},
#        {'from_index': 2913,
#         'to_index': 2932,
#         'distance': 460,
#         'time': 23.506,
#         'instruction': {'text': 'Bear right onto Carretera Oaxaca-Zimatlán de Álvarez.'}},
#        {'from_index': 2932,
#         'to_index': 3012,
#         'distance': 6168,
#         'time': 450.535,
#         'instruction': {'text': 'Bear left to stay on Carretera Oaxaca-Zimatlán de Álvarez.'}},
#        {'from_index': 3012,
#         'to_index': 3018,
#         'distance': 35,
#         'time': 5.438,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit onto Carretera Oaxaca-Zachila.'}},
#        {'from_index': 3018,
#         'to_index': 3188,
#         'distance': 15411,
#         'time': 741.396,
#         'instruction': {'text': 'Exit the roundabout onto Carretera Oaxaca-Zachila.'}},
#        {'from_index': 3188,
#         'to_index': 3195,
#         'distance': 503,
#         'time': 24.376,
#         'instruction': {'text': 'Turn right onto Carretera Oaxaca - Puerto Escondido/MEX 131.'}},
#        {'from_index': 3195,
#         'to_index': 3517,
#         'distance': 35540,
#         'time': 1714.216,
#         'instruction': {'text': 'Turn left to stay on Carretera Oaxaca - Puerto Escondido/MEX 131.'}},
#        {'from_index': 3517,
#         'to_index': 3577,
#         'distance': 4008,
#         'time': 288.768,
#         'instruction': {'text': 'Keep left at the fork.'}},
#        {'from_index': 3577,
#         'to_index': 3627,
#         'distance': 2388,
#         'time': 172.568,
#         'instruction': {'text': 'Bear left.'}},
#        {'from_index': 3627,
#         'to_index': 5168,
#         'distance': 54301,
#         'time': 2617.202,
#         'instruction': {'text': 'Make a sharp left onto Carretera Oaxaca - Puerto Escondido/MEX 131. Continue on MEX 131.'}},
#        {'from_index': 5168,
#         'to_index': 5366,
#         'distance': 4185,
#         'time': 201.185,
#         'instruction': {'text': 'Bear right onto Carretera Oaxaca - Puerto Escondido/MEX 131.'}},
#        {'from_index': 5366,
#         'to_index': 7068,
#         'distance': 47825,
#         'time': 2297.521,
#         'instruction': {'text': 'Turn left to stay on Carretera Oaxaca - Puerto Escondido/MEX 131.'}},
#        {'from_index': 7068,
#         'to_index': 7510,
#         'distance': 13707,
#         'time': 659.132,
#         'instruction': {'text': 'Turn left onto Carretera Oaxaca - Puerto Escondido/MEX 131. Continue on MEX 131.'}},
#        {'from_index': 7510,
#         'to_index': 7733,
#         'distance': 7063,
#         'time': 339.595,
#         'instruction': {'text': 'Turn right onto Carretera Oaxaca - Puerto Escondido/MEX 131.'}},
#        {'from_index': 7733,
#         'to_index': 7991,
#         'distance': 11701,
#         'time': 562.414,
#         'instruction': {'text': 'Turn right onto Carretera Oaxaca - Puerto Escondido/MEX 131. Continue on MEX 131.'}},
#        {'from_index': 7991,
#         'to_index': 7992,
#         'distance': 24,
#         'time': 2.312,
#         'instruction': {'text': 'Turn left to stay on MEX 131.'}},
#        {'from_index': 7992,
#         'to_index': 8023,
#         'distance': 1164,
#         'time': 57.964,
#         'instruction': {'text': 'Turn left onto Calle Corregidora/MEX 131.'}},
#        {'from_index': 8023,
#         'to_index': 8111,
#         'distance': 2247,
#         'time': 108.162,
#         'instruction': {'text': 'Turn right onto Calle Corregidora/MEX 131. Continue on MEX 131.'}},
#        {'from_index': 8111,
#         'to_index': 8423,
#         'distance': 8511,
#         'time': 410.751,
#         'instruction': {'text': 'Turn left onto Carretera Oaxaca - Puerto Escondido/MEX 131.'}},
#        {'from_index': 8423,
#         'to_index': 9495,
#         'distance': 31258,
#         'time': 1570.285,
#         'instruction': {'text': 'Turn right onto Carretera Oaxaca - Puerto Escondido/MEX 131.'}},
#        {'from_index': 9495,
#         'to_index': 9507,
#         'distance': 1088,
#         'time': 54.48,
#         'instruction': {'text': 'Turn left onto MEX 200/Carretera Costera.'}},
#        {'from_index': 9507,
#         'to_index': 9516,
#         'distance': 634,
#         'time': 46.019,
#         'instruction': {'text': 'Turn right onto Calle Tercera Poniente.'}},
#        {'from_index': 9516,
#         'to_index': 9522,
#         'distance': 155,
#         'time': 17.349,
#         'instruction': {'text': 'Turn right onto Privada Zaachila.'}},
#        {'from_index': 9522,
#         'to_index': 9522,
#         'distance': 0,
#         'time': 0,
#         'instruction': {'text': 'Your destination is on the left.'}}]},
#      {'distance': 4692672,
#       'time': 184821.234,
#       'steps': [{'from_index': 0,
#         'to_index': 6,
#         'distance': 184,
#         'time': 19.042,
#         'instruction': {'text': 'Drive northeast on Privada Zaachila.'}},
#        {'from_index': 6,
#         'to_index': 7,
#         'distance': 87,
#         'time': 14.343,
#         'instruction': {'text': 'Turn left.'}},
#        {'from_index': 7,
#         'to_index': 8,
#         'distance': 58,
#         'time': 7.873,
#         'instruction': {'text': 'Turn right onto Calle Quinta Sur.'}},
#        {'from_index': 8,
#         'to_index': 13,
#         'distance': 366,
#         'time': 43.298,
#         'instruction': {'text': 'Turn left onto Calle Segunda Poniente.'}},
#        {'from_index': 13,
#         'to_index': 18,
#         'distance': 102,
#         'time': 13.293,
#         'instruction': {'text': 'Turn right onto Calle Primera Sur.'}},
#        {'from_index': 18,
#         'to_index': 541,
#         'distance': 46826,
#         'time': 2234.901,
#         'instruction': {'text': 'Turn left onto MEX 200/Carretera Costera. Continue on MEX 200.'}},
#        {'from_index': 541,
#         'to_index': 2729,
#         'distance': 171652,
#         'time': 7258.158,
#         'instruction': {'text': 'Keep left to stay on MEX 200.'}},
#        {'from_index': 2729,
#         'to_index': 4361,
#         'distance': 161880,
#         'time': 7526.543,
#         'instruction': {'text': 'Keep left to stay on MEX 200.'}},
#        {'from_index': 4361,
#         'to_index': 4426,
#         'distance': 14732,
#         'time': 506.826,
#         'instruction': {'text': 'Take the MEX 95D ramp toward Mexico.'},
#         'toll': True},
#        {'from_index': 4426,
#         'to_index': 4666,
#         'distance': 20079,
#         'time': 688.587,
#         'instruction': {'text': 'Keep left at the fork.'}},
#        {'from_index': 4666,
#         'to_index': 4687,
#         'distance': 1195,
#         'time': 48.38,
#         'instruction': {'text': 'Take the exit.'}},
#        {'from_index': 4687,
#         'to_index': 4714,
#         'distance': 2180,
#         'time': 110.984,
#         'instruction': {'text': 'Turn left onto MEX 95.'}},
#        {'from_index': 4714,
#         'to_index': 4717,
#         'distance': 77,
#         'time': 2.46,
#         'instruction': {'text': 'Continue on MEX 95/Libramiento a México.'}},
#        {'from_index': 4717,
#         'to_index': 4991,
#         'distance': 21034,
#         'time': 836.203,
#         'instruction': {'text': 'Bear right onto MEX 200/Carretera Acapulco-Zihuatanejo. Continue on MEX 200.'}},
#        {'from_index': 4991,
#         'to_index': 5826,
#         'distance': 89899,
#         'time': 3543.164,
#         'instruction': {'text': 'Keep left to stay on MEX 200.'}},
#        {'from_index': 5826,
#         'to_index': 7555,
#         'distance': 142423,
#         'time': 5747.849,
#         'instruction': {'text': 'Keep left to stay on MEX 200.'}},
#        {'from_index': 7555,
#         'to_index': 7759,
#         'distance': 24095,
#         'time': 964.568,
#         'instruction': {'text': 'Keep left to stay on MEX 200.'}},
#        {'from_index': 7759,
#         'to_index': 7763,
#         'distance': 101,
#         'time': 4.728,
#         'instruction': {'text': 'Take the MEX 37D exit toward Urupan/Morelia.'}},
#        {'from_index': 7763,
#         'to_index': 7774,
#         'distance': 488,
#         'time': 22.837,
#         'instruction': {'text': 'Keep right to take MEX 37D toward Urupan/Morelia.'},
#         'toll': True},
#        {'from_index': 7774,
#         'to_index': 10107,
#         'distance': 187308,
#         'time': 6353.724,
#         'instruction': {'text': 'Bear right onto MEX 37D/Entronque Uruapan - Lázaro Cárdenas.'},
#         'toll': True},
#        {'from_index': 10107,
#         'to_index': 10109,
#         'distance': 306,
#         'time': 10.023,
#         'instruction': {'text': 'Stay straight to take the ramp toward Uruapan.'}},
#        {'from_index': 10109,
#         'to_index': 10263,
#         'distance': 12534,
#         'time': 559.605,
#         'instruction': {'text': 'Keep left to take MEX 14D toward Uruapan.'},
#         'toll': True},
#        {'from_index': 10263,
#         'to_index': 10279,
#         'distance': 1460,
#         'time': 105.632,
#         'instruction': {'text': 'Turn left onto Avenida Lázaro Cárdenas/MEX 14.'}},
#        {'from_index': 10279,
#         'to_index': 10285,
#         'distance': 480,
#         'time': 32.574,
#         'instruction': {'text': 'Turn right onto Avenida Latinoamericana.'}},
#        {'from_index': 10285,
#         'to_index': 10288,
#         'distance': 20,
#         'time': 2.652,
#         'instruction': {'text': 'Enter the roundabout and take the 1st exit toward Guadalajara.'}},
#        {'from_index': 10288,
#         'to_index': 10328,
#         'distance': 2306,
#         'time': 146.25,
#         'instruction': {'text': 'Exit the roundabout toward Guadalajara.'}},
#        {'from_index': 10328,
#         'to_index': 10880,
#         'distance': 35060,
#         'time': 1683.832,
#         'instruction': {'text': 'Turn left onto Calzada Benito Juárez/MEX 37. Continue on MEX 37.'}},
#        {'from_index': 10880,
#         'to_index': 10892,
#         'distance': 46,
#         'time': 6.699,
#         'instruction': {'text': 'Enter the roundabout and take the 4th exit onto Carapan - Playa Azul/MEX 37.'}},
#        {'from_index': 10892,
#         'to_index': 11741,
#         'distance': 40525,
#         'time': 1893.019,
#         'instruction': {'text': 'Exit the roundabout onto Carapan - Playa Azul/MEX 37. Continue on MEX 37.'}},
#        {'from_index': 11741,
#         'to_index': 11837,
#         'distance': 4386,
#         'time': 201.738,
#         'instruction': {'text': 'Bear right onto Calle Nacional/MEX 37. Continue on MEX 37.'}},
#        {'from_index': 11837,
#         'to_index': 12240,
#         'distance': 37527,
#         'time': 1805.167,
#         'instruction': {'text': 'Turn left onto Carretera Carapan-La Piedad/MEX 37. Continue on MEX 37.'}},
#        {'from_index': 12240,
#         'to_index': 12247,
#         'distance': 82,
#         'time': 4.546,
#         'instruction': {'text': 'Turn left.'}},
#        {'from_index': 12247,
#         'to_index': 12249,
#         'distance': 153,
#         'time': 8.171,
#         'instruction': {'text': 'Turn left onto Carretera La Piedad-Carapan/MEX 37.'}},
#        {'from_index': 12249,
#         'to_index': 13090,
#         'distance': 127783,
#         'time': 4383.3,
#         'instruction': {'text': 'Take the MEX 15D ramp.'},
#         'toll': True},
#        {'from_index': 13090,
#         'to_index': 13315,
#         'distance': 30979,
#         'time': 1292.082,
#         'instruction': {'text': 'Take the MEX 15D exit on the left.'},
#         'toll': True},
#        {'from_index': 13315,
#         'to_index': 13392,
#         'distance': 8029,
#         'time': 384.226,
#         'instruction': {'text': 'Keep left to take MEX 15D/MEX 70/MEX 90.'}},
#        {'from_index': 13392,
#         'to_index': 13530,
#         'distance': 12816,
#         'time': 577.398,
#         'instruction': {'text': 'Keep left to take MEX 15D/MEX 70/MEX 90/Autopista Guadalajara - Tepic.'}},
#        {'from_index': 13530,
#         'to_index': 13576,
#         'distance': 9945,
#         'time': 325.515,
#         'instruction': {'text': 'Keep right to stay on MEX 15D.'},
#         'toll': True},
#        {'from_index': 13576,
#         'to_index': 13801,
#         'distance': 47311,
#         'time': 1587.312,
#         'instruction': {'text': 'Keep left to take MEX 15D/Autopista Guadalajara - Tepic.'},
#         'toll': True},
#        {'from_index': 13801,
#         'to_index': 14415,
#         'distance': 47719,
#         'time': 1608.683,
#         'instruction': {'text': 'Keep left to stay on MEX 15D/Autopista Guadalajara - Tepic.'},
#         'toll': True},
#        {'from_index': 14415,
#         'to_index': 14646,
#         'distance': 39533,
#         'time': 1293.917,
#         'instruction': {'text': 'Keep left to stay on MEX 15D/Autopista Guadalajara - Tepic.'},
#         'toll': True},
#        {'from_index': 14646,
#         'to_index': 14693,
#         'distance': 17961,
#         'time': 587.914,
#         'instruction': {'text': 'Keep right to stay on MEX 15D/Autopista Guadalajara - Tepic.'},
#         'toll': True},
#        {'from_index': 14693,
#         'to_index': 14702,
#         'distance': 646,
#         'time': 58.148,
#         'instruction': {'text': 'Take the MEX 15D exit toward Mazatlan/Culiacan/Libramiento Norte de Tepic.'},
#         'toll': True},
#        {'from_index': 14702,
#         'to_index': 14908,
#         'distance': 28161,
#         'time': 1032.128,
#         'instruction': {'text': 'Keep right to take MEX 15D toward Mazatlan/Culiacan/Libramiento Norte de Tepic.'},
#         'toll': True},
#        {'from_index': 14908,
#         'to_index': 20395,
#         'distance': 858184,
#         'time': 30140.246,
#         'instruction': {'text': 'Take the exit toward Mazatlán.'},
#         'toll': True},
#        {'from_index': 20395,
#         'to_index': 20446,
#         'distance': 8315,
#         'time': 285.171,
#         'instruction': {'text': 'Keep left to take MEX 15D/Carretera Navojoa - Ciudad Obregón.'}},
#        {'from_index': 20446,
#         'to_index': 21287,
#         'distance': 131125,
#         'time': 4690.039,
#         'instruction': {'text': 'Keep right to stay on MEX 15D.'},
#         'toll': True},
#        {'from_index': 21287,
#         'to_index': 22124,
#         'distance': 121278,
#         'time': 4028.335,
#         'instruction': {'text': 'Keep left to stay on MEX 15D.'}},
#        {'from_index': 22124,
#         'to_index': 22354,
#         'distance': 40591,
#         'time': 1391.796,
#         'instruction': {'text': 'Keep right to take MEX 15D.'}},
#        {'from_index': 22354,
#         'to_index': 22960,
#         'distance': 155088,
#         'time': 5568.664,
#         'instruction': {'text': 'Take the MEX 15D exit.'}},
#        {'from_index': 22960,
#         'to_index': 23632,
#         'distance': 104091,
#         'time': 3966.046,
#         'instruction': {'text': 'Take the MEX 2D exit on the left.'},
#         'toll': True},
#        {'from_index': 23632,
#         'to_index': 23993,
#         'distance': 60957,
#         'time': 2967.664,
#         'instruction': {'text': 'Turn left onto Calle Álvaro Obregón/SON 44. Continue on SON 44.'}},
#        {'from_index': 23993,
#         'to_index': 24564,
#         'distance': 112738,
#         'time': 4598.593,
#         'instruction': {'text': 'Turn right toward SON 3.'}},
#        {'from_index': 24564,
#         'to_index': 24572,
#         'distance': 101,
#         'time': 9.875,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit onto SON 3.'}},
#        {'from_index': 24572,
#         'to_index': 24625,
#         'distance': 5461,
#         'time': 246.21,
#         'instruction': {'text': 'Exit the roundabout onto SON 3.'}},
#        {'from_index': 24625,
#         'to_index': 25439,
#         'distance': 135487,
#         'time': 5422.593,
#         'instruction': {'text': 'Turn right onto Carretera Costera/SON 3.'}},
#        {'from_index': 25439,
#         'to_index': 25783,
#         'distance': 67038,
#         'time': 2825.195,
#         'instruction': {'text': 'Turn right onto Carretera Golfo de Santa Clara-San Luis Río Colorado/SON 3. Continue on SON 3.'}},
#        {'from_index': 25783,
#         'to_index': 25857,
#         'distance': 5110,
#         'time': 236.687,
#         'instruction': {'text': 'Turn right onto Carretera San Luis Río Colorado-Golfo de Santa Clara/SON 3. Continue on SON 3.'}},
#        {'from_index': 25857,
#         'to_index': 25890,
#         'distance': 2902,
#         'time': 171.875,
#         'instruction': {'text': 'Turn left onto Carretera Luis B. Sánchez/SON 34. Continue on SON 34.'}},
#        {'from_index': 25890,
#         'to_index': 26153,
#         'distance': 30138,
#         'time': 1476.476,
#         'instruction': {'text': 'Turn right onto Calle Bolivia/BC 4. Continue on BC 4.'}},
#        {'from_index': 26153,
#         'to_index': 26210,
#         'distance': 7253,
#         'time': 442.226,
#         'instruction': {'text': 'Turn left onto Enlace Ejido Cucapah Mestizo/BC 41.'}},
#        {'from_index': 26210,
#         'to_index': 26845,
#         'distance': 156809,
#         'time': 7534.593,
#         'instruction': {'text': 'Turn left onto Carretera Mexicali-San Felipe/MEX 5. Continue on MEX 5.'}},
#        {'from_index': 26845,
#         'to_index': 28354,
#         'distance': 198984,
#         'time': 9655.593,
#         'instruction': {'text': 'Turn left onto Carretera San Felipe-Laguna Chapala/MEX 5.'}},
#        {'from_index': 28354,
#         'to_index': 29383,
#         'distance': 252385,
#         'time': 9535.343,
#         'instruction': {'text': 'Turn left onto MEX 1/Carretera Lázaro Cárdenas-Punta Prieta. Continue on MEX 1.'}},
#        {'from_index': 29383,
#         'to_index': 36322,
#         'distance': 459559,
#         'time': 18071.031,
#         'instruction': {'text': 'Keep left to stay on MEX 1.'}},
#        {'from_index': 36322,
#         'to_index': 38152,
#         'distance': 230167,
#         'time': 9344.765,
#         'instruction': {'text': 'Turn left onto MEX 1/Boulevard Benito Juárez/Transpeninsular Highway. Continue on Transpeninsular Highway.'}},
#        {'from_index': 38152,
#         'to_index': 38182,
#         'distance': 1250,
#         'time': 59.078,
#         'instruction': {'text': 'Keep right to take MEX 1 South/Boulevard General Augustín Olachea Avilés.'}},
#        {'from_index': 38182,
#         'to_index': 38231,
#         'distance': 3348,
#         'time': 167.578,
#         'instruction': {'text': 'Turn right onto MEX 1/Libramiento Sur Daniel Roldán Zimbrón.'}},
#        {'from_index': 38231,
#         'to_index': 38465,
#         'distance': 25879,
#         'time': 1097.328,
#         'instruction': {'text': 'Turn right onto MEX 1/Boulevard Forjadores de Sudcalifornia. Continue on MEX 1.'}},
#        {'from_index': 38465,
#         'to_index': 39710,
#         'distance': 116731,
#         'time': 4684.281,
#         'instruction': {'text': 'Take the MEX 19 exit.'}},
#        {'from_index': 39710,
#         'to_index': 39808,
#         'distance': 9026,
#         'time': 473.375,
#         'instruction': {'text': 'Take the MEX 19 exit.'}},
#        {'from_index': 39808,
#         'to_index': 39815,
#         'distance': 321,
#         'time': 25.437,
#         'instruction': {'text': 'Turn left onto MEX 1/Boulevard Constituyentes.'}},
#        {'from_index': 39815,
#         'to_index': 39822,
#         'distance': 369,
#         'time': 33.265,
#         'instruction': {'text': 'Keep right to stay on Boulevard Constituyentes.'}},
#        {'from_index': 39822,
#         'to_index': 39840,
#         'distance': 1432,
#         'time': 133.546,
#         'instruction': {'text': 'Turn right onto Avenida Leona Vicario.'}},
#        {'from_index': 39840,
#         'to_index': 39840,
#         'distance': 0,
#         'time': 0,
#         'instruction': {'text': 'Your destination is on the left.'}}]},
#      {'distance': 4156281,
#       'time': 163007.5,
#       'steps': [{'from_index': 0,
#         'to_index': 4,
#         'distance': 327,
#         'time': 28.491,
#         'instruction': {'text': 'Drive southeast on Avenida Leona Vicario.'}},
#        {'from_index': 4,
#         'to_index': 30,
#         'distance': 1074,
#         'time': 76.21,
#         'instruction': {'text': 'Turn left onto Boulevard Lazaro Cardenas.'}},
#        {'from_index': 30,
#         'to_index': 57,
#         'distance': 1155,
#         'time': 113.967,
#         'instruction': {'text': 'Turn left onto MEX 1/Boulevard Constituyentes.'}},
#        {'from_index': 57,
#         'to_index': 82,
#         'distance': 1320,
#         'time': 73.813,
#         'instruction': {'text': 'Take the MEX 19 exit on the left.'}},
#        {'from_index': 82,
#         'to_index': 184,
#         'distance': 9065,
#         'time': 492.039,
#         'instruction': {'text': 'Turn right onto MEX 19/Boulevard Miguel Hidalgo. Continue on MEX 19.'}},
#        {'from_index': 184,
#         'to_index': 1399,
#         'distance': 116137,
#         'time': 4657.764,
#         'instruction': {'text': 'Stay straight to take the MEX 19 ramp.'}},
#        {'from_index': 1399,
#         'to_index': 1664,
#         'distance': 26533,
#         'time': 1119.087,
#         'instruction': {'text': 'Take the MEX 1 exit on the left.'}},
#        {'from_index': 1664,
#         'to_index': 1715,
#         'distance': 3388,
#         'time': 178.723,
#         'instruction': {'text': 'Turn left onto MEX 1/Libramiento Sur Daniel Roldán Zimbrón.'}},
#        {'from_index': 1715,
#         'to_index': 3406,
#         'distance': 203001,
#         'time': 8213.784,
#         'instruction': {'text': 'Turn left onto MEX 1 North/Boulevard General Augustín Olachea Avilés.'}},
#        {'from_index': 3406,
#         'to_index': 3562,
#         'distance': 28391,
#         'time': 1176.057,
#         'instruction': {'text': 'Keep left to take MEX 1/Transpeninsular Highway.'}},
#        {'from_index': 3562,
#         'to_index': 10509,
#         'distance': 457438,
#         'time': 17980.622,
#         'instruction': {'text': 'Turn right onto MEX 1/Carretera Transpeninsular/Transpeninsular Highway. Continue on MEX 1.'}},
#        {'from_index': 10509,
#         'to_index': 11559,
#         'distance': 254464,
#         'time': 9624.785,
#         'instruction': {'text': 'Keep left to stay on MEX 1.'}},
#        {'from_index': 11559,
#         'to_index': 13068,
#         'distance': 198983,
#         'time': 9650.5,
#         'instruction': {'text': 'Turn right onto Carretera San Felipe-Laguna Chapala/MEX 5.'}},
#        {'from_index': 13068,
#         'to_index': 13206,
#         'distance': 10114,
#         'time': 489.195,
#         'instruction': {'text': 'Turn right onto Mar Caribe Sur/MEX 5. Continue on MEX 5.'}},
#        {'from_index': 13206,
#         'to_index': 13752,
#         'distance': 146785,
#         'time': 7047.761,
#         'instruction': {'text': 'Bear left onto Carretera a San Felipe/MEX 5. Continue on MEX 5.'}},
#        {'from_index': 13752,
#         'to_index': 13809,
#         'distance': 7253,
#         'time': 438.203,
#         'instruction': {'text': 'Turn right onto Enlace Ejido Cucapah Mestizo/BC 41.'}},
#        {'from_index': 13809,
#         'to_index': 14074,
#         'distance': 30145,
#         'time': 1468.597,
#         'instruction': {'text': 'Turn right onto Carretera El Faro-Estación Coahuila/BC 4. Continue on BC 4.'}},
#        {'from_index': 14074,
#         'to_index': 14107,
#         'distance': 2903,
#         'time': 173.441,
#         'instruction': {'text': 'Turn left onto Calle 5 de Mayo/SON 34. Continue on SON 34.'}},
#        {'from_index': 14107,
#         'to_index': 14181,
#         'distance': 5110,
#         'time': 238.683,
#         'instruction': {'text': 'Turn right onto Carretera San Luis Río Colorado-Golfo de Santa Clara/SON 3. Continue on SON 3.'}},
#        {'from_index': 14181,
#         'to_index': 14526,
#         'distance': 67040,
#         'time': 2824.808,
#         'instruction': {'text': 'Turn left onto Carretera San Luis Río Colorado-Golfo de Santa Clara/SON 3. Continue on SON 3.'}},
#        {'from_index': 14526,
#         'to_index': 15341,
#         'distance': 135498,
#         'time': 5425.664,
#         'instruction': {'text': 'Turn left onto Carretera Costera/SON 3.'}},
#        {'from_index': 15341,
#         'to_index': 15394,
#         'distance': 5455,
#         'time': 251.679,
#         'instruction': {'text': 'Turn left onto Libramiento Puerto Peñasco/SON 3. Continue on SON 3.'}},
#        {'from_index': 15394,
#         'to_index': 15403,
#         'distance': 93,
#         'time': 8.945,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit onto SON 3.'}},
#        {'from_index': 15403,
#         'to_index': 15784,
#         'distance': 86081,
#         'time': 3634.953,
#         'instruction': {'text': 'Exit the roundabout onto SON 3.'}},
#        {'from_index': 15784,
#         'to_index': 15970,
#         'distance': 26755,
#         'time': 970.968,
#         'instruction': {'text': 'Keep right to stay on SON 3.'}},
#        {'from_index': 15970,
#         'to_index': 16293,
#         'distance': 57659,
#         'time': 2672.718,
#         'instruction': {'text': 'Turn left onto Caborca - El Desemboque/SON 44. Continue on SON 44.'}},
#        {'from_index': 16293,
#         'to_index': 16338,
#         'distance': 2494,
#         'time': 163.476,
#         'instruction': {'text': 'Turn left onto Avenida Aeropuerto.'}},
#        {'from_index': 16338,
#         'to_index': 16541,
#         'distance': 14013,
#         'time': 608.273,
#         'instruction': {'text': 'Make a sharp right toward MEX 2.'}},
#        {'from_index': 16541,
#         'to_index': 17240,
#         'distance': 94302,
#         'time': 3571.828,
#         'instruction': {'text': 'Stay straight to take the MEX 2 ramp.'},
#         'toll': True},
#        {'from_index': 17240,
#         'to_index': 17834,
#         'distance': 155029,
#         'time': 5421.828,
#         'instruction': {'text': 'Turn right onto MEX 15D/Boulevard Internacional. Continue on MEX 15D.'}},
#        {'from_index': 17834,
#         'to_index': 19869,
#         'distance': 301871,
#         'time': 10737.953,
#         'instruction': {'text': 'Take the MEX 15D exit on the left.'},
#         'toll': True},
#        {'from_index': 19869,
#         'to_index': 21467,
#         'distance': 252786,
#         'time': 8923.656,
#         'instruction': {'text': 'Keep right to stay on MEX 15D.'}},
#        {'from_index': 21467,
#         'to_index': 23763,
#         'distance': 342985,
#         'time': 11781.765,
#         'instruction': {'text': 'Keep left to stay on MEX 15D.'},
#         'toll': True},
#        {'from_index': 23763,
#         'to_index': 25333,
#         'distance': 261315.99999999997,
#         'time': 9361.328,
#         'instruction': {'text': 'Keep left to stay on MEX 15D.'},
#         'toll': True},
#        {'from_index': 25333,
#         'to_index': 25340,
#         'distance': 383,
#         'time': 15.5,
#         'instruction': {'text': 'Take the exit toward Libramiento Norte de Tepic/Guadalajara.'}},
#        {'from_index': 25340,
#         'to_index': 25582,
#         'distance': 29839,
#         'time': 1047.039,
#         'instruction': {'text': 'Keep left to take MEX 15D/Libramiento Norte de Tepic toward Libramiento Norte de Tepic/Guadalajara.'},
#         'toll': True},
#        {'from_index': 25582,
#         'to_index': 25591,
#         'distance': 677,
#         'time': 49.64,
#         'instruction': {'text': 'Make a left U-turn to stay on MEX 15D/Libramiento Norte de Tepic.'},
#         'toll': True},
#        {'from_index': 25591,
#         'to_index': 25599,
#         'distance': 251,
#         'time': 45.187,
#         'instruction': {'text': 'Take the exit toward Autopista Tepic – Guadalajara.'},
#         'toll': True},
#        {'from_index': 25599,
#         'to_index': 25659,
#         'distance': 18416,
#         'time': 643.632,
#         'instruction': {'text': 'Keep left to take MEX 15D/Autopista Guadalajara - Tepic toward Guadalajara Cuota.'},
#         'toll': True},
#        {'from_index': 25659,
#         'to_index': 26324,
#         'distance': 76145,
#         'time': 2521.296,
#         'instruction': {'text': 'Keep left to stay on MEX 15D/Autopista Guadalajara - Tepic.'},
#         'toll': True},
#        {'from_index': 26324,
#         'to_index': 26627,
#         'distance': 52570,
#         'time': 1776.328,
#         'instruction': {'text': 'Keep left to stay on MEX 15D.'},
#         'toll': True},
#        {'from_index': 26627,
#         'to_index': 26641,
#         'distance': 5795,
#         'time': 189.812,
#         'instruction': {'text': 'Keep left to take MEX 15D/Autopista Guadalajara - Tepic.'},
#         'toll': True},
#        {'from_index': 26641,
#         'to_index': 26910,
#         'distance': 29249,
#         'time': 1186.343,
#         'instruction': {'text': 'Keep right to stay on MEX 15D.'},
#         'toll': True},
#        {'from_index': 26910,
#         'to_index': 26920,
#         'distance': 685,
#         'time': 36.218,
#         'instruction': {'text': 'Keep right to take MEX 15D/MEX 70/MEX 90/Calzada Lázaro Cárdenas.'}},
#        {'from_index': 26920,
#         'to_index': 26933,
#         'distance': 1465,
#         'time': 85.265,
#         'instruction': {'text': 'Keep left to stay on MEX 15D/MEX 70/MEX 90/Calzada Lázaro Cárdenas.'}},
#        {'from_index': 26933,
#         'to_index': 27185,
#         'distance': 33312,
#         'time': 1384.656,
#         'instruction': {'text': 'Keep left to stay on MEX 15D/Calzada Lázaro Cárdenas toward Tonala/Tlaquepaque/Chapala.'},
#         'toll': True},
#        {'from_index': 27185,
#         'to_index': 27637,
#         'distance': 117438,
#         'time': 3933.671,
#         'instruction': {'text': 'Take the MEX GUA 10D exit toward León/Aguascalientes/Tepatitlan/Lagos de Moreno.'},
#         'toll': True},
#        {'from_index': 27637,
#         'to_index': 27715,
#         'distance': 23152,
#         'time': 772.109,
#         'instruction': {'text': 'Keep right to stay on MEX 80D/Autopista Lagos de Moreno - Zapotlanejo toward Mexico/Leon/Aguascalientes.'}},
#        {'from_index': 27715,
#         'to_index': 27942,
#         'distance': 53291,
#         'time': 1748.765,
#         'instruction': {'text': 'Take the MEX 45D exit toward MEX 57/Mexico City/Leon.'},
#         'toll': True},
#        {'from_index': 27942,
#         'to_index': 28345,
#         'distance': 76935,
#         'time': 2659.328,
#         'instruction': {'text': 'Keep left to take MEX 43D.'},
#         'toll': True},
#        {'from_index': 28345,
#         'to_index': 28374,
#         'distance': 786,
#         'time': 31.812,
#         'instruction': {'text': 'Take the ramp toward Querétaro.'},
#         'toll': True},
#        {'from_index': 28374,
#         'to_index': 28551,
#         'distance': 54235,
#         'time': 1878.234,
#         'instruction': {'text': 'Keep left to take MEX 45D toward Morelia.'},
#         'toll': True},
#        {'from_index': 28551,
#         'to_index': 29187,
#         'distance': 83172,
#         'time': 2730.296,
#         'instruction': {'text': 'Keep right to take MEX 47D toward Mexico/San Juan Del Rio.'},
#         'toll': True},
#        {'from_index': 29187,
#         'to_index': 29233,
#         'distance': 1132,
#         'time': 84.14,
#         'instruction': {'text': 'Take the MEX 55 exit.'}},
#        {'from_index': 29233,
#         'to_index': 29244,
#         'distance': 209,
#         'time': 30.171,
#         'instruction': {'text': 'Continue.'}},
#        {'from_index': 29244,
#         'to_index': 29269,
#         'distance': 2932,
#         'time': 105.64,
#         'instruction': {'text': 'Bear right onto MEX 57/Supercarretera México-Queretaro.'}},
#        {'from_index': 29269,
#         'to_index': 30246,
#         'distance': 81302,
#         'time': 3432.093,
#         'instruction': {'text': 'Take the exit toward Queretaro/Tequisquaipan.'}},
#        {'from_index': 30246,
#         'to_index': 31115,
#         'distance': 32888,
#         'time': 1558.234,
#         'instruction': {'text': 'Bear left onto MEX 85.'}},
#        {'from_index': 31115,
#         'to_index': 32043,
#         'distance': 19716,
#         'time': 948.75,
#         'instruction': {'text': 'Bear left to stay on MEX 85.'}},
#        {'from_index': 32043,
#         'to_index': 32431,
#         'distance': 11332,
#         'time': 544.343,
#         'instruction': {'text': 'Turn right to stay on MEX 85.'}},
#        {'from_index': 32431,
#         'to_index': 32455,
#         'distance': 338,
#         'time': 16.89,
#         'instruction': {'text': 'Turn left to stay on MEX 85.'}},
#        {'from_index': 32455,
#         'to_index': 33592,
#         'distance': 40066,
#         'time': 1928.312,
#         'instruction': {'text': 'Turn left to stay on MEX 85.'}},
#       [-110.212325, 23.48266],
#       [-110.212235, 23.483007],
#       [-110.212139, 23.483294],
#       [-110.21206, 23.483522],
#       [-110.211935, 23.483819],
#       [-110.21183, 23.484041],
#       [-110.211598, 23.484514],
#       [-110.211462, 23.484773],
#       [-110.211228, 23.48523],
#       [-110.210981, 23.485676],
#       [-110.210783, 23.486058],
#       [-110.210676, 23.486251],
#       [-110.210544, 23.486454],
#       [-110.210086, 23.487319],
#       [-110.20975, 23.487974],
#       [-110.20929, 23.488865],
#       [-110.208824, 23.489762],
#       [-110.208345, 23.49069],
#       [-110.207874, 23.491629],
#       [-110.207182, 23.493018],
#       [-110.206863, 23.493602],
#       [-110.206558, 23.494189],
#       [-110.206121, 23.495071],
#       [-110.205637, 23.495994],
#       [-110.205275, 23.496717],
#       [-110.204984, 23.497325],
#       [-110.204736, 23.497895],
#       [-110.204448, 23.498546],
#       [-110.202815, 23.502256],
#       [-110.202144, 23.503826],
#       [-110.201779, 23.504691],
#       [-110.201485, 23.505363],
#       [-110.201173, 23.506084],
#       [-110.200988, 23.506492],
#       [-110.200554, 23.507514],
#       [-110.200231, 23.508247],
#       [-110.199908, 23.508975],
#       [-110.199397, 23.510187],
#       [-110.198797, 23.511587],
#       [-110.198372, 23.51258],
#       [-110.19812, 23.513155],
#       [-110.197896, 23.513671],
#       [-110.197605, 23.514352],
#       [-110.197, 23.515746],
#       [-110.196359, 23.517209],
#       [-110.196134, 23.517741],
#       [-110.195942, 23.51819],
#       ...]]}}],
#  'properties': {'mode': 'drive',
#   'waypoints': [{'lat': 18.8333, 'lon': -97.15},
#    {'lat': 18.8333, 'lon': -97.15},
#    {'lat': 15.85, 'lon': -97.0667},
#    {'lat': 22.8909, 'lon': -109.9124},
#    {'lat': 21.0167, 'lon': -99.1833}],
#   'units': 'metric'},
#  'type': 'FeatureCollection'}

# %% [markdown]
# ## From the JSON response, store the route's legs coordinates in a variable called `legs`

# %%
# Fetch the route's legs coordinates from the JSON reponse
legs = route_response['time']
legs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25044\1534703535.py in <module>
#       1 # Fetch the route's legs coordinates from the JSON reponse
# ----> 2 legs = route_response['time']
#       3 legs
#
# KeyError: 'time'

# %% [markdown]
# ## Loop through the route legs coordinates to fetch the latitude and longitude for each step. Store the latitude and longitude value into two Python lists names `longitude` and `latitude`

# %%
# Create and empty list to store the longitude of each step
# YOUR CODE HERE

# Create and empty list to store the latitude of step
# YOUR CODE HERE

# Loop through the legs coordinates to fetch the latitude and longitude for each step
# YOUR CODE HERE

# %% [markdown]
# ## Use the `longitude` and `latitude` Python lists to create a new DataFrame named `route_df`

# %%
# Create an empty DataFrame to store the steps' coordinates
route_df = # YOUR CODE HERE

# Add the steps' longitude and latitude from each step as columns to the DataFrame
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
# Out:
#    longitude   latitude
# 0  12.479944  41.889982
# 1  12.479927  41.890012
# 2  12.479760  41.890249
# 3  12.479580  41.890493
# 4  12.479418  41.890662

# %% [markdown]
# ##  Use the GeoViews `Path` function to configure a line plot by using `route_df`. Set a custom color and width for the line that may contrast with the map

# %%
# Configure the route path by using the GeoViews' Path function
route_path = # YOUR CODE HERE

# %%
# Display a composed plot by using the route_map and route_path objects
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country,Current Description)
#    .Path.I   :Path   [longitude,latitude]
